# %% [markdown]
# ### Git and Github

# %% [markdown]
# Il codice seguente genera un grafico a partire dal dataset dei consumi di elettricità in germania.
#
# L'esercizio richiede di trasformare questo codice in un python script chiamato ```main.py``` che genera questo grafico e lo salva sul disco.
#
# Dopodiché, l'idea è quella di caricare questo codice in una nuova repository (per esempio ```my_first_repo```) che abbia questa struttura:
#
# - datasets/OPSD_Germany_all.csv # contiene il dataset
# - main.py # il codice che legge il dataset e genera una immagine
# - figure.png # l'immagine generata dal codice
# - notebooks/traccia.ipynb
#
# **Importante**: solo questi files vanno caricati nella repo, tutti gli altri (per esempio i .ipynb_checkpoints, file pycache e altri files generati automaticamente da python), vanno ignorati.
#
# Qui avete il risultato finale che dovreste ottenere: https://github.com/mttga/neural_academy_first_repo/tree/main

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv(
    'dataset/OPSD_Germany_all.csv',
    parse_dates=True,
    index_col='Date'
)
df['Consumption'].plot(figsize=(15, 6),
                       marker='.',
                       markersize=3,
                       linestyle='')
plt.title('Consumptions')
plt.show()
